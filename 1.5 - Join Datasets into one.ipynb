# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
from natsort import natsorted
import scipy.stats as stats
import networkx as nx
import os

# %%
# Get the list of all files and directories
path = ".\\1 - Output\datasets"
dir_list = os.listdir(path)
pathwaysNames=[]
for file in dir_list:
    if file not in ["BP","CombinedDF.csv"]:
        pathwaysNames.append(file[:-4])

# %%
cols = ['Age_Discrete', 'Sex', 'Smoking','SPY_Discrete', 'Stage', 'Status', 'TMB_Discrete','PatientID']
datasets={}
patientInPathways={}
allPatients=[]
for sp in pathwaysNames:
    sp = sp.split(".csv")[0]
    
    spName = sp.split(" - ")[0]
    cols.append(sp)

    datasets[sp] = pd.read_csv(".\\1 - Output\datasets\\"+sp+".csv",sep="\t",usecols=cols)
    datasets[sp]=datasets[sp].rename(columns={'Age_Discrete': 'Age'})
    datasets[sp]=datasets[sp].rename(columns={'SPY_Discrete': 'SPY'})
    datasets[sp]=datasets[sp].rename(columns={'TMB_Discrete': 'TMB'})
    cols.pop()

    allPatients.extend(list(pd.read_csv(".\\1 - Output\datasets\\"+sp+".csv",sep="\t",usecols=["PatientID"])["PatientID"]))

# %%
print("Repeting Patient",len(allPatients))
print("Unique Patient",len(set(allPatients)))
# Out:
# Repeting Patient 4652
# Unique Patient 1044

# %% [markdown]
# ## Joining Dataframes

# %%
features=[]
features.extend(list(datasets['Cell-Cell communication'].columns)[1:-1])
features.extend(list(datasets.keys()))
len(features),features#all patient and tumor features + all SP or subpathways with significant intersections
# Out:
# (19,
#  ['Age',
#   'Sex',
#   'Smoking',
#   'SPY',
#   'Stage',
#   'Status',
#   'TMB',
#   'Cell-Cell communication',
#   'Cellular responses to stimuli -- Oncogene Induced Senescence',
#   'Chromatin organization -- PKMTs methylate histone lysines',
#   'Developmental Biology',
#   'Extracellular matrix organization',
#   'Gene expression (Transcription) -- Transcriptional regulation by RUNX3',
#   'Immune System -- Dectin-2 family',
#   'Metabolism of proteins -- SUMOylation',
#   'Neuronal System',
#   'Programmed Cell Death -- Activation of NOXA and translocation to mitochondria',
#   'Signal Transduction',
#   'Vesicle-mediated transport -- Scavenging by Class H Receptors'])

# %%
combinedDF=pd.DataFrame(index=list(set(allPatients)), columns=features)
combinedDF = combinedDF.map(lambda x: np.nan)

# Set dtype for the patients and tomur variables
for column in combinedDF.columns[:7]:
    combinedDF[column] = combinedDF[column].astype('object')

for column in combinedDF.columns[7:]:
    combinedDF[column] = combinedDF[column].astype('Int64')

combinedDF.head()
# Out:
#                        Age  Sex Smoking  SPY Stage Status  TMB  \
# LUAD-CHTN-MAD08-00104  NaN  NaN     NaN  NaN   NaN    NaN  NaN
# LUAD-D01751            NaN  NaN     NaN  NaN   NaN    NaN  NaN
# TCGA-44-7660           NaN  NaN     NaN  NaN   NaN    NaN  NaN
# TCGA-55-6983           NaN  NaN     NaN  NaN   NaN    NaN  NaN
# TCGA-55-6985           NaN  NaN     NaN  NaN   NaN    NaN  NaN
#
#                        Cell-Cell communication  \
# LUAD-CHTN-MAD08-00104                     <NA>
# LUAD-D01751                               <NA>
# TCGA-44-7660                              <NA>
# TCGA-55-6983                              <NA>
# TCGA-55-6985                              <NA>
#
#                        Cellular responses to stimuli -- Oncogene Induced Senescence  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
#
#                        Chromatin organization -- PKMTs methylate histone lysines  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
#
#                        Developmental Biology  \
# LUAD-CHTN-MAD08-00104                   <NA>
# LUAD-D01751                             <NA>
# TCGA-44-7660                            <NA>
# TCGA-55-6983                            <NA>
# TCGA-55-6985                            <NA>
#
#                        Extracellular matrix organization  \
# LUAD-CHTN-MAD08-00104                               <NA>
# LUAD-D01751                                         <NA>
# TCGA-44-7660                                        <NA>
# TCGA-55-6983                                        <NA>
# TCGA-55-6985                                        <NA>
#
#                        Gene expression (Transcription) -- Transcriptional regulation by RUNX3  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
#
#                        Immune System -- Dectin-2 family  \
# LUAD-CHTN-MAD08-00104                              <NA>
# LUAD-D01751                                        <NA>
# TCGA-44-7660                                       <NA>
# TCGA-55-6983                                       <NA>
# TCGA-55-6985                                       <NA>
#
#                        Metabolism of proteins -- SUMOylation  Neuronal System  \
# LUAD-CHTN-MAD08-00104                                   <NA>             <NA>
# LUAD-D01751                                             <NA>             <NA>
# TCGA-44-7660                                            <NA>             <NA>
# TCGA-55-6983                                            <NA>             <NA>
# TCGA-55-6985                                            <NA>             <NA>
#
#                        Programmed Cell Death -- Activation of NOXA and translocation to mitochondria  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
#
#                        Signal Transduction  \
# LUAD-CHTN-MAD08-00104                 <NA>
# LUAD-D01751                           <NA>
# TCGA-44-7660                          <NA>
# TCGA-55-6983                          <NA>
# TCGA-55-6985                          <NA>
#
#                        Vesicle-mediated transport -- Scavenging by Class H Receptors
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>

# %% [markdown]
# ### Iterate all dataframes and update the combined dataframe with the info from indivuduals dfs

# %%
for df in datasets.values():
    for index, row in df.iterrows():
        features = list(row.keys())
        pId = row[features[0]]
        for f in features[1:]:
            if f in ["Age","Sex","Smoking","SPY","Stage","Status","TMB"]:
                combinedDF.at[pId,f]=row[f]
            else:
                combinedDF.at[pId,f]=int(row[f])

# %%
row[f],f
# Out:
# (1, 'Vesicle-mediated transport -- Scavenging by Class H Receptors')

# %%
combinedDF
# Out:
#                          Age     Sex         Smoking      SPY Stage  \
# LUAD-CHTN-MAD08-00104    NaN    Male             NaN      NaN   NaN
# LUAD-D01751              NaN  Female  Current Smoker    15-29    IB
# TCGA-44-7660           69-74    Male  Current Smoker  118-132    IB
# TCGA-55-6983           80-85    Male   Reformed <=15    59-74   IIB
# TCGA-55-6985           54-59  Female   Reformed <=15    44-59    IB
# ...                      ...     ...             ...      ...   ...
# TCGA-85-7696           59-64    Male   Reformed <=15    29-44    IA
# TCGA-22-4604           69-74    Male  Current Smoker    44-59   IIA
# TCGA-97-7941           69-74  Female    Reformed >15    15-29    IA
# TCGA-18-5592           54-59    Male    Reformed >15    29-44   IIB
# TCGA-22-5481           69-74  Female   Reformed <=15    74-88   IIB
#
#                            Status    TMB  Cell-Cell communication  \
# LUAD-CHTN-MAD08-00104         NaN    4-8                     <NA>
# LUAD-D01751                   NaN    4-8                     <NA>
# TCGA-44-7660             0:LIVING   8-13                     <NA>
# TCGA-55-6983             0:LIVING    0-4                     <NA>
# TCGA-55-6985             0:LIVING  13-17                        6
# ...                           ...    ...                      ...
# TCGA-85-7696             0:LIVING    4-8                     <NA>
# TCGA-22-4604           1:DECEASED    4-8                        4
# TCGA-97-7941             0:LIVING    0-4                     <NA>
# TCGA-18-5592             0:LIVING   8-13                     <NA>
# TCGA-22-5481           1:DECEASED   8-13                     <NA>
#
#                        Cellular responses to stimuli -- Oncogene Induced Senescence  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                           2
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
# ...                                                                  ...
# TCGA-85-7696                                                        <NA>
# TCGA-22-4604                                                        <NA>
# TCGA-97-7941                                                        <NA>
# TCGA-18-5592                                                        <NA>
# TCGA-22-5481                                                           2
#
#                        Chromatin organization -- PKMTs methylate histone lysines  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
# ...                                                                  ...
# TCGA-85-7696                                                           2
# TCGA-22-4604                                                        <NA>
# TCGA-97-7941                                                        <NA>
# TCGA-18-5592                                                        <NA>
# TCGA-22-5481                                                           2
#
#                        Developmental Biology  \
# LUAD-CHTN-MAD08-00104                   <NA>
# LUAD-D01751                               13
# TCGA-44-7660                            <NA>
# TCGA-55-6983                            <NA>
# TCGA-55-6985                              19
# ...                                      ...
# TCGA-85-7696                            <NA>
# TCGA-22-4604                              13
# TCGA-97-7941                               6
# TCGA-18-5592                              21
# TCGA-22-5481                            <NA>
#
#                        Extracellular matrix organization  \
# LUAD-CHTN-MAD08-00104                               <NA>
# LUAD-D01751                                         <NA>
# TCGA-44-7660                                           9
# TCGA-55-6983                                        <NA>
# TCGA-55-6985                                           9
# ...                                                  ...
# TCGA-85-7696                                        <NA>
# TCGA-22-4604                                        <NA>
# TCGA-97-7941                                        <NA>
# TCGA-18-5592                                          10
# TCGA-22-5481                                           7
#
#                        Gene expression (Transcription) -- Transcriptional regulation by RUNX3  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                            3
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
# ...                                                                  ...
# TCGA-85-7696                                                        <NA>
# TCGA-22-4604                                                        <NA>
# TCGA-97-7941                                                           2
# TCGA-18-5592                                                           4
# TCGA-22-5481                                                        <NA>
#
#                        Immune System -- Dectin-2 family  \
# LUAD-CHTN-MAD08-00104                              <NA>
# LUAD-D01751                                        <NA>
# TCGA-44-7660                                       <NA>
# TCGA-55-6983                                       <NA>
# TCGA-55-6985                                          2
# ...                                                 ...
# TCGA-85-7696                                          2
# TCGA-22-4604                                       <NA>
# TCGA-97-7941                                       <NA>
# TCGA-18-5592                                       <NA>
# TCGA-22-5481                                       <NA>
#
#                        Metabolism of proteins -- SUMOylation  Neuronal System  \
# LUAD-CHTN-MAD08-00104                                      4             <NA>
# LUAD-D01751                                             <NA>               11
# TCGA-44-7660                                            <NA>             <NA>
# TCGA-55-6983                                            <NA>             <NA>
# TCGA-55-6985                                            <NA>               11
# ...                                                      ...              ...
# TCGA-85-7696                                               5             <NA>
# TCGA-22-4604                                            <NA>                7
# TCGA-97-7941                                            <NA>                4
# TCGA-18-5592                                               5             <NA>
# TCGA-22-5481                                            <NA>             <NA>
#
#                        Programmed Cell Death -- Activation of NOXA and translocation to mitochondria  \
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                            1
# TCGA-44-7660                                                           1
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                           1
# ...                                                                  ...
# TCGA-85-7696                                                           1
# TCGA-22-4604                                                           1
# TCGA-97-7941                                                        <NA>
# TCGA-18-5592                                                           1
# TCGA-22-5481                                                           1
#
#                        Signal Transduction  \
# LUAD-CHTN-MAD08-00104                   15
# LUAD-D01751                             19
# TCGA-44-7660                          <NA>
# TCGA-55-6983                            12
# TCGA-55-6985                          <NA>
# ...                                    ...
# TCGA-85-7696                          <NA>
# TCGA-22-4604                            23
# TCGA-97-7941                            10
# TCGA-18-5592                            31
# TCGA-22-5481                          <NA>
#
#                        Vesicle-mediated transport -- Scavenging by Class H Receptors
# LUAD-CHTN-MAD08-00104                                               <NA>
# LUAD-D01751                                                         <NA>
# TCGA-44-7660                                                        <NA>
# TCGA-55-6983                                                        <NA>
# TCGA-55-6985                                                        <NA>
# ...                                                                  ...
# TCGA-85-7696                                                        <NA>
# TCGA-22-4604                                                           1
# TCGA-97-7941                                                           1
# TCGA-18-5592                                                        <NA>
# TCGA-22-5481                                                        <NA>
#
# [1044 rows x 19 columns]

# %%
combinedDF.isnull().sum()
# Out:
# Age                                                                              168
# Sex                                                                                3
# Smoking                                                                           51
# SPY                                                                              233
# Stage                                                                             31
# Status                                                                           144
# TMB                                                                                0
# Cell-Cell communication                                                          705
# Cellular responses to stimuli -- Oncogene Induced Senescence                     767
# Chromatin organization -- PKMTs methylate histone lysines                        807
# Developmental Biology                                                            455
# Extracellular matrix organization                                                526
# Gene expression (Transcription) -- Transcriptional regulation by RUNX3           798
# Immune System -- Dectin-2 family                                                 765
# Metabolism of proteins -- SUMOylation                                            714
# Neuronal System                                                                  616
# Programmed Cell Death -- Activation of NOXA and translocation to mitochondria    388
# Signal Transduction                                                              526
# Vesicle-mediated transport -- Scavenging by Class H Receptors                    809
# dtype: int64

# %%
combinedDF.to_csv("1 - Output/datasets/CombinedDF.csv",sep="\t",index=True)
